# %%
from numpy import *
from pandas import *
import pandas as pd
import numpy as np
from IPython.display import display
from io import StringIO
import matplotlib.pyplot as plt

# %% [markdown]
# # Ocupando libre office para la tabla #

# %%
pandas.read_csv('pacientes.csv')
# Out:
#      Nombre Apellido Sexo  Edad Hipertenciòn  Diabetes
# 0    Andres   Torres    H    54            SI       SI
# 1     Paola    Lopez    M    21            NO       NO
# 2  Patricia  Jimenez    M    36            NO       SI
# 3   Daniela     Ruiz    M    12            NO       NO
# 4    Hernan     Diaz    H    16            NO       NO
# 5   Vanessa  Sànchez    M    19            NO       NO
# 6  Patricia   Rivera    M    45            SI       NO
# 7      Omar   Santos    H    33            SI       SI
# 8     Erick    Ochoa    H    48            NO       SI

# %%
datos = pd.read_csv('pacientes.csv')
datos.head()
# Out:
#      Nombre Apellido Sexo  Edad Hipertenciòn  Diabetes
# 0    Andres   Torres    H    54            SI       SI
# 1     Paola    Lopez    M    21            NO       NO
# 2  Patricia  Jimenez    M    36            NO       SI
# 3   Daniela     Ruiz    M    12            NO       NO
# 4    Hernan     Diaz    H    16            NO       NO

# %%
datos.shape
# Out:
# (9, 6)

# %%
datos.count()
# Out:
# Nombre           9
# Apellido         9
# Sexo             9
# Edad             9
# Hipertenciòn     9
# Diabetes         9
# dtype: int64

# %%
datos.describe()
# Out:
#             Edad
# count   9.000000
# mean   31.555556
# std    15.289793
# min    12.000000
# 25%    19.000000
# 50%    33.000000
# 75%    45.000000
# max    54.000000

# %% [markdown]
# ## Graficar con pandas ##

# %%
pd.crosstab(datos.Sexo, datos.Diabetes)
# Out:
# Diabetes  NO  SI
# Sexo
# H          1   3
# M          4   1

# %%
graf= pd.crosstab(datos.Sexo, datos.Diabetes)

# %%
fig = plt.figure(figsize=(30,10)) #Figura de 30x10 pixeles
graf.plot(kind='bar', alpha=0.5)
plt.title('SEXO VS DIABETES')
# Out:
# Text(0.5, 1.0, 'SEXO VS DIABETES')

# %% [markdown]
# ## Agregar columnas ##

# %%
Masdatos = datos.copy()
Masdatos["HIJOS"] = [1, 0, 1, 0, 2, 0, 3, 4, 1]
Masdatos
# Out:
#      Nombre Apellido Sexo  Edad Hipertenciòn  Diabetes  HIJOS
# 0    Andres   Torres    H    54            SI       SI      1
# 1     Paola    Lopez    M    21            NO       NO      0
# 2  Patricia  Jimenez    M    36            NO       SI      1
# 3   Daniela     Ruiz    M    12            NO       NO      0
# 4    Hernan     Diaz    H    16            NO       NO      2
# 5   Vanessa  Sànchez    M    19            NO       NO      0
# 6  Patricia   Rivera    M    45            SI       NO      3
# 7      Omar   Santos    H    33            SI       SI      4
# 8     Erick    Ochoa    H    48            NO       SI      1

# %%
pd.crosstab(Masdatos.Edad, Masdatos.HIJOS)
# Out:
# HIJOS  0  1  2  3  4
# Edad
# 12     1  0  0  0  0
# 16     0  0  1  0  0
# 19     1  0  0  0  0
# 21     1  0  0  0  0
# 33     0  0  0  0  1
# 36     0  1  0  0  0
# 45     0  0  0  1  0
# 48     0  1  0  0  0
# 54     0  1  0  0  0
